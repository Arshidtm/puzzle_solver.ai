# %%
print('hello')
# Out:
# hello

# %%
from PIL import Image
import cv2

# %%
import pytesseract

# %%
image=cv2.imread('mathpuzzle1.jpg')

grey = cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)


text=pytesseract.image_to_string(grey)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File c:\Users\arshi\Downloads\Desktop\Brototype\puzzle\env\Lib\site-packages\pytesseract\pytesseract.py:255, in run_tesseract(input_filename, output_filename_base, extension, lang, config, nice, timeout)
#     254 try:
# --> 255     proc = subprocess.Popen(cmd_args, **subprocess_args())
#     256 except OSError as e:
#
# File ~\Lib\subprocess.py:1026, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask, pipesize, process_group)
#    1023             self.stderr = io.TextIOWrapper(self.stderr,
#    1024                     encoding=encoding, errors=errors)
# ...

# %%
pip install tesseract
# Out:
# ...
#      ---------------------------------------- 0.0/45.6 MB ? eta -:--:--
#      ---------------------------------------- 0.0/45.6 MB ? eta -:--:--
#      --------------------------------------- 0.0/45.6 MB 131.3 kB/s eta 0:05:47
#      --------------------------------------- 0.0/45.6 MB 131.3 kB/s eta 0:05:47
#      --------------------------------------- 0.1/45.6 MB 219.0 kB/s eta 0:03:28
#      --------------------------------------- 0.1/45.6 MB 262.6 kB/s eta 0:02:54
#      --------------------------------------- 0.1/45.6 MB 425.1 kB/s eta 0:01:47
#      --------------------------------------- 0.2/45.6 MB 686.8 kB/s eta 0:01:06
#      --------------------------------------- 0.2/45.6 MB 686.8 kB/s eta 0:01:06
#      --------------------------------------- 0.3/45.6 MB 632.7 kB/s eta 0:01:12
#      --------------------------------------- 0.3/45.6 MB 592.4 kB/s eta 0:01:17
#      --------------------------------------- 0.3/45.6 MB 592.4 kB/s eta 0:01:17
# ...

# %%
img=cv2.imread('img_2.webp')

gray=cv2.cvtColor()
